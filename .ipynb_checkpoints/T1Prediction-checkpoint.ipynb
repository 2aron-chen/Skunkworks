# %%
from torch.utils.data import DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F
import pickle
from torchmetrics import StructuralSimilarityIndexMeasure
from statistics import median, mean
from matplotlib import pyplot as plt
import numpy as np
from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM
import json
from tqdm import tqdm
from glob import glob
import sys
path = "/study3/mrphys/skunkworks/kk/mriUnet"
sys.path.insert(0,path)
import unet
from torchvision import transforms
from torch.utils.data import Dataset
import h5py
from sklearn.model_selection import KFold as kf
import os
import nibabel as nib

T1path = sorted(glob('/study3/mrphys/skunkworks/training_data/mover01/*/processed_data/T1_3_tv.nii'))
xPath = sorted(glob('/scratch/mrphys/denoised/denoised_*.h5'))
gtPath = sorted(glob('/study3/mrphys/skunkworks/training_data/mover01/*/processed_data/C.h5'))

def slice2d(array, discardZero=False):
    '''
    slice a 4d array of shape (c-channel, n, n, n) where n in the cube length
    into 3d arrays slices of shape (c, n, n) per each 2d plane
    '''
    result = []
    c, w, h, d = array.shape
    assert (w==h)and(h==d)and(d==w), f"Array must be cubic, got: {w}x{h}x{d}"
    for i in range(w):
        result.append(array[:,i,:,:])
        result.append(array[:,:,i,:])
        result.append(array[:,:,:,i])
    return np.array(result)

def getComplexSlices(path, return_scale=False):

    with h5py.File(path,'r') as hf:
        prefix = 'C_000_0'
        imagestackReal = []
        imagestackImag = []
        for i in range(6):
            n = prefix + str(i).zfill(2)
            image = hf['Images'][n]
            imagestackReal.append(np.array(image['real']))
            imagestackImag.append(np.array(image['imag']))
            if i==0:
                normScale = np.max([np.abs(np.array(image['real'])).max(), np.abs(np.array(image['imag'])).max()])
        imagestackReal = np.array(imagestackReal)/normScale
        imagestackImag = np.array(imagestackImag)/normScale
        imagesliceReal = slice2d(imagestackReal)
        imagesliceImag = slice2d(imagestackImag)
        
    if return_scale:
        return imagesliceReal+imagesliceImag*1j, normScale
    else:
        return imagesliceReal+imagesliceImag*1j
    
class T1Dataset(Dataset):
    
    def __init__(self, index, gt=False, norm_factor=1000):
    
        if gt:
            self.x_path = gtPath[index]
        else:
            self.x_path = xPath[index]  
        self.y_path = T1path[index]
        
        self.x = list(getComplexSlices(self.x_path))
        self.y = list(slice2d(np.transpose(nib.load(self.y_path).get_fdata()).reshape(1,256,256,256)/norm_factor))

    def __getitem__(self, index):
        return self.x[index], self.y[index]

    def __len__(self):
        return len(self.x)
    
def predict(model, dataset, device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")):
    model.eval()
    model.to(device)
    X = []
    X0 = []
    Y = []
    Y0 = []
    Z = []
    Z0 = []
    for i, (pca, y) in tqdm(enumerate(dataset)):
        pca = torch.tensor(pca).to(device).unsqueeze(0)
        with torch.no_grad():
            p = torch.abs(model(pca)).cpu().numpy()
            if i%3==0:
                X.append(p)
                X0.append(np.expand_dims(y,0))
            elif i%3==1:
                Y.append(p)
                Y0.append(np.expand_dims(y,0))
            else:
                Z.append(p)
                Z0.append(np.expand_dims(y,0))
                
    pred = np.vstack(X).transpose(1,0,2,3), np.vstack(Y).transpose(1,2,0,3), np.vstack(Z).transpose(1,2,3,0)
    y = np.vstack(X0).transpose(1,0,2,3), np.vstack(Y0).transpose(1,2,0,3), np.vstack(Z0).transpose(1,2,3,0)
                   
    return pred, y

def get_prediction(idx, name='T1', fold=1, gt=False):
    
    name=f'{name}_{fold}'
    if gt:
        with open(f'/scratch/mrphys/pickled/T1dataset_{idx}.pickle', 'rb') as f:
            dataset = pickle.load(f)
    else:
        with open(f'/scratch/mrphys/pickled/T1dataset2_{idx}.pickle', 'rb') as f:
            dataset = pickle.load(f)
            
    order = ['separable convolution', 'relu']
    if 'bn' in name:
        order.append('batch norm')
    
    mapper = unet.UNet(6,
            1,
            f_maps=32,
            layer_order=['separable convolution', 'relu','batch norm'],
            depth=3,
            layer_growth=2.0,
            residual=True,
            complex_input=True,
            complex_kernel=True,
            ndims=2,
            padding=1)
    mapper.load_state_dict(torch.load(f'/study/mrphys/skunkworks/kk/outputs/{name}/weights/{name}_LATEST.pth'))

    (X, Y, Z), (X0, Y0, Z0) = predict(mapper, dataset)
    
    return (X+Y+Z)/3, (X0+Y0+Z0)/3

# %%
kfsplitter = kf(n_splits=5, shuffle=True, random_state=69420)
for train_index, test_index in kfsplitter.split(gtPath):
    print(test_index)
# Out:
# [ 4  7 13 16 20 21 24 31 37 40 42 56 61]
# [ 3  5  8 25 26 35 43 47 49 51 60 62 63]
# [ 6 12 17 18 19 28 32 34 36 45 48 50 58]
# [ 0  1  2  9 11 14 23 27 29 33 39 52 54]
# [10 15 22 30 38 41 44 46 53 55 57 59 64]

# %%
pred_denoised, y = get_prediction(4, name='T1_denoised_GAN', gt=False)
pred, y = get_prediction(4, name='T1', gt=True)
# Out:
# Crop amount [(-4, -4, -4, -4), (-16, -16, -16, -16)]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 pred_denoised, y = get_prediction(4, name='T1_denoised_GAN', gt=False)
#       2 pred, y = get_prediction(4, name='T1', gt=True)
#
# Cell In [4], line 138, in get_prediction(idx, name, fold, gt)
#     125     order.append('batch norm')
#     127 mapper = unet.UNet(6,
#     128 1,
#     129 f_maps=32,
#    (...)
#     136 ndims=2,
#     137 padding=1)
# --> 138 mapper.load_state_dict(torch.load(f'/study/mrphys/skunkworks/kk/outputs/{name}/weights/{name}_LATEST.pth'))
#     140 (X, Y, Z), (X0, Y0, Z0) = predict(mapper, dataset)
#     142 return (X+Y+Z)/3, (X0+Y0+Z0)/3
#
# File ~/.conda/envs/mriDenoise/lib/python3.9/site-packages/torch/nn/modules/module.py:1604, in Module.load_state_dict(self, state_dict, strict)
#    1599         error_msgs.insert(
#    1600             0, 'Missing key(s) in state_dict: {}. '.format(
#    1601                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1603 if len(error_msgs) > 0:
# -> 1604     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1605                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1606 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for UNet:
# 	Unexpected key(s) in state_dict: "encoders.0.basic_module.SingleConv1.batchnorm2.bn_r.weight", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_r.bias", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_r.running_mean", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_r.running_var", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_r.num_batches_tracked", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_i.weight", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_i.bias", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_i.running_mean", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_i.running_var", "encoders.0.basic_module.SingleConv1.batchnorm2.bn_i.num_batches_tracked", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_r.weight", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_r.bias", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_r.running_mean", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_r.running_var", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_r.num_batches_tracked", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_i.weight", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_i.bias", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_i.running_mean", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_i.running_var", "encoders.0.basic_module.SingleConv2.batchnorm2.bn_i.num_batches_tracked", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_r.weight", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_r.bias", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_r.running_mean", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_r.running_var", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_r.num_batches_tracked", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_i.weight", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_i.bias", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_i.running_mean", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_i.running_var", "encoders.1.basic_module.SingleConv1.batchnorm2.bn_i.num_batches_tracked", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_r.weight", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_r.bias", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_r.running_mean", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_r.running_var", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_r.num_batches_tracked", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_i.weight", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_i.bias", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_i.running_mean", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_i.running_var", "encoders.1.basic_module.SingleConv2.batchnorm2.bn_i.num_batches_tracked", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_r.weight", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_r.bias", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_r.running_mean", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_r.running_var", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_r.num_batches_tracked", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_i.weight", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_i.bias", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_i.running_mean", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_i.running_var", "encoders.2.basic_module.SingleConv1.batchnorm2.bn_i.num_batches_tracked", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_r.weight", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_r.bias", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_r.running_mean", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_r.running_var", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_r.num_batches_tracked", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_i.weight", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_i.bias", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_i.running_mean", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_i.running_var", "encoders.2.basic_module.SingleConv2.batchnorm2.bn_i.num_ ...

# %%
n = 150

fig, ax = plt.subplots(1,3,figsize=(15,5))
plt.gray()
ax[0].axis('off')
ax[0].imshow(np.abs(pred[0,n]), vmin=0, vmax=6)
ax[0].set_title("Pred, From 9 mins")
ax[1].axis('off')
ax[1].imshow(np.abs(pred_denoised[0,n]), vmin=0, vmax=6)
ax[1].set_title("Pred, From Denoised 2 mins")
ax[2].axis('off')
ax[2].imshow(np.abs(y[0,n]), vmin=0, vmax=6)
ax[2].set_title("Ground Truth T1 Mapping")
plt.show()

# %%
masks = sorted(glob('/scratch/mrphys/masks_for_kk/*/processed_data/mpnrage_composite_bfc_tv.anat/FAST_OUTPUT/T1_fast_seg_resliced.nii.gz'))

# %%
mask = nib.load(masks[4]).get_fdata()==2

print('9 mins Preformance on White Matter')

mae = np.mean(np.abs(pred*mask - y*mask))*1000
mse = np.mean(np.abs(pred*mask - y*mask)**2)
print(mae, mse, sep='\n')

print('2 mins Preformance on White Matter')

mae = np.mean(np.abs(pred_denoised*mask - y*mask))*1000
mse = np.mean(np.abs(pred_denoised*mask - y*mask)**2)
print(mae, mse, sep='\n')
# Out:
# 9 mins Preformance on White Matter
# 4.368688523996032
# 0.0018688400588277832
# 2 mins Preformance on White Matter
# 5.726199539484487
# 0.004225349820368901

# %% [markdown]
# # Denoiser : 2 min PCA -> "9 min" PCA
#
# # T1 Prediction : 9 min PCA -> 9 min T1 B1 and other params
#
# # 2 min PCA -> "9 min" PCA -> 9 min T1 B1 and other params
#
# # 2 min PCA -> 9 min T1 B1 and other params

# %%
e = nib.load(masks[4]).get_fdata()
plt.imshow(e[150])
plt.colorbar()
